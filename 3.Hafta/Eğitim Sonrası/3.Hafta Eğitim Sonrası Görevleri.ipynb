# %% [markdown]
# # Problem 1
# Kullanıcıdan bir sayı alınız. Sayı 0'dan büyükse pozitif , 0'dan küçükse negatif sıfıra eşitse sıfır yazdırınız.

# %%
sayi = int(input("Sayi gir:"))

if sayi>0:
    print("Pozitif")
elif sayi<0:
    print("Negatif")
else:
    print("sıfır")
# Out:
# sıfır

# %% [markdown]
#  # Problem 2
# Kullanıcıdan aldığınız bir sayının mükemmel olup olmadığını bulmaya çalışın.
# Bir sayının kendi hariç bölenlerinin toplamı kendine eşitse bu sayıya "mükemmel sayı" denir. Örnek olarak, 6 mükemmel bir sayıdır. (1 + 2 + 3 = 6)

# %%
sayi = int(input("Sayı gir: "))

toplam = 0

for i in range(1, sayi//2 + 1):
    if sayi % i == 0:
        toplam += i

if sayi == toplam:
    print(f"{sayi} bir mükemmel sayıdır.")
else:
    print(f"{sayi} bir mükemmel sayı değildir.")
# Out:
# 63 bir mükemmel sayı değildir. 31

# %% [markdown]
#  # Problem 3
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.
# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.
#
# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

# %%
sayi = str(input("Sayı gir: "))
basamakSayisi = len(sayi)
toplam=0

for i in sayi:
    toplam += int(i)**basamakSayisi

if toplam == int(sayi):
    print(f"{sayi} sayisi armstorngtur.")
else:
    print("Armstorng değil.")
# Out:
# 1634 sayisi armstorngtur.

# %% [markdown]
# # Problem 4
# YetGen Core Python mezunu bir öğretmenimiz öğrencilerine 1'den 10'a kadar sayılarla çarpım tablosunu öğretirken Python'dan destek almak istiyor. Bu konuda öğretmenimize yardımcı olmak ister misin?
#
# İpucu: İç içe 2 tane for döngüsü kullanın.
#
# Aynı zamanda sayıları range() fonksiyonunu kullanarak elde edin.

# %%
n=10

for i in range(1,n):
    for j in range(1,n):
        print(f"{i}x{j}= ", i*j)
# Out:
# 1x1=  1
# 1x2=  2
# 1x3=  3
# 1x4=  4
# 1x5=  5
# 1x6=  6
# 1x7=  7
# 1x8=  8
# 1x9=  9
# 2x1=  2
# 2x2=  4
# 2x3=  6
# 2x4=  8
# 2x5=  10
# 2x6=  12
# 2x7=  14
# 2x8=  16
# 2x9=  18
# 3x1=  3
# 3x2=  6
# 3x3=  9
# 3x4=  12
# 3x5=  15
# 3x6=  18
# 3x7=  21
# 3x8=  24
# 3x9=  27
# 4x1=  4
# 4x2=  8
# 4x3=  12
# 4x4=  16
# 4x5=  20
# 4x6=  24
# 4x7=  28
# 4x8=  32
# 4x9=  36
# 5x1=  5
# 5x2=  10
# 5x3=  15
# 5x4=  20
# 5x5=  25
# 5x6=  30
# 5x7=  35
# 5x8=  40
# 5x9=  45
# 6x1=  6
# 6x2=  12
# 6x3=  18
# 6x4=  24
# 6x5=  30
# 6x6=  36
# 6x7=  42
# 6x8=  48
# 6x9=  54
# 7x1=  7
# 7x2=  14
# 7x3=  21
# 7x4=  28
# 7x5=  35
# 7x6=  42
# 7x7=  49
# 7x8=  56
# 7x9=  63
# 8x1=  8
# 8x2=  16
# 8x3=  24
# 8x4=  32
# 8x5=  40
# 8x6=  48
# 8x7=  56
# 8x8=  64
# 8x9=  72
# 9x1=  9
# 9x2=  18
# 9x3=  27
# 9x4=  36
# 9x5=  45
# 9x6=  54
# 9x7=  63
# 9x8=  72
# 9x9=  81

# %% [markdown]
# # Problem 5
# Markete giren bir YetGen'li sıra beklememek için hızlı kasaya gider. Hızlı kasanın çalışma mantığı şu şekildedir:
# - Kullanıcının aldığı her ürünün fiyatını tek tek girmesi gerekir.
# - Kullanıcı kasadan çıkmak isterse q tuşuna basmalıdır.
# - Kasa girilen fiyatları son fiyat isimli değişkene ekler.
# - Değişkeni ekrana bastırır.
#
# İpucu: while döngüsünü sonsuz koşulla başlatın ve kullanıcı q'ya basarsa döngüyü break ile sonlandırın.

# %%
sonFiyat=0

while True:
    fiyat = (input("Ürün Fiyatı:"))
    if fiyat == "q":
        break
    sonFiyat += int(fiyat)

print(f"Toplam Tutar {sonFiyat} €")
# Out:
# Toplam Tutar 183 €

# %% [markdown]
# # Problem 6
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi continue ile yapmaya çalışın.

# %%
for i in range(1,101):
    if i%3!=0:
        continue

    print(f"{i} sayısı 3e tam bölünür.")
# Out:
# 3 sayısı 3e tam bölünür.
# 6 sayısı 3e tam bölünür.
# 9 sayısı 3e tam bölünür.
# 12 sayısı 3e tam bölünür.
# 15 sayısı 3e tam bölünür.
# 18 sayısı 3e tam bölünür.
# 21 sayısı 3e tam bölünür.
# 24 sayısı 3e tam bölünür.
# 27 sayısı 3e tam bölünür.
# 30 sayısı 3e tam bölünür.
# 33 sayısı 3e tam bölünür.
# 36 sayısı 3e tam bölünür.
# 39 sayısı 3e tam bölünür.
# 42 sayısı 3e tam bölünür.
# 45 sayısı 3e tam bölünür.
# 48 sayısı 3e tam bölünür.
# 51 sayısı 3e tam bölünür.
# 54 sayısı 3e tam bölünür.
# 57 sayısı 3e tam bölünür.
# 60 sayısı 3e tam bölünür.
# 63 sayısı 3e tam bölünür.
# 66 sayısı 3e tam bölünür.
# 69 sayısı 3e tam bölünür.
# 72 sayısı 3e tam bölünür.
# 75 sayısı 3e tam bölünür.
# 78 sayısı 3e tam bölünür.
# 81 sayısı 3e tam bölünür.
# 84 sayısı 3e tam bölünür.
# 87 sayısı 3e tam bölünür.
# 90 sayısı 3e tam bölünür.
# 93 sayısı 3e tam bölünür.
# 96 sayısı 3e tam bölünür.
# 99 sayısı 3e tam bölünür.

# %% [markdown]
# # Problem 7
# Bir YetGen Core Python mezunu MEF Üniversitesi'nde Bilgisayar Bilimleri Doktora programının mülakatına girmeye hak kazanıyor. Mülakata hazırlanırken internetten soru araştırıyor. Karşısına çıkan ünlü FizzBuzz sorusuna benzer YetGen sorusunda kendisini yeterince hazır hissetmiyor. Bu soruyu çözmesine destek olmak ister misin?
#
# Soru aşağıdaki gibidir:
#
# 1’den 100’e kadar sayıları yazdırıyoruz. Ancak eğer sayı 3’e bölünüyor ise Yet, sayı 5’e bölünüyorsa Gen, hem 3’e hem 5’e bölünüyorsa YetGen yazdırıyoruz.

# %%
for i in range(1,101):
    if i%3==0 and i%5==0 :
        print(f"{i} YetGen")
    elif i%3==0:
        print(f"{i} Yet")
    elif i%5==0:
        print(f"{i} Gen")
    else:
        print(i)
# Out:
# 1
# 2
# 3 Yet
# 4
# 5 Gen
# 6 Yet
# 7
# 8
# 9 Yet
# 10 Gen
# 11
# 12 Yet
# 13
# 14
# 15 YetGen
# 16
# 17
# 18 Yet
# 19
# 20 Gen
# 21 Yet
# 22
# 23
# 24 Yet
# 25 Gen
# 26
# 27 Yet
# 28
# 29
# 30 YetGen
# 31
# 32
# 33 Yet
# 34
# 35 Gen
# 36 Yet
# 37
# 38
# 39 Yet
# 40 Gen
# 41
# 42 Yet
# 43
# 44
# 45 YetGen
# 46
# 47
# 48 Yet
# 49
# 50 Gen
# 51 Yet
# 52
# 53
# 54 Yet
# 55 Gen
# 56
# 57 Yet
# 58
# 59
# 60 YetGen
# 61
# 62
# 63 Yet
# 64
# 65 Gen
# 66 Yet
# 67
# 68
# 69 Yet
# 70 Gen
# 71
# 72 Yet
# 73
# 74
# 75 YetGen
# 76
# 77
# 78 Yet
# 79
# 80 Gen
# 81 Yet
# 82
# 83
# 84 Yet
# 85 Gen
# 86
# 87 Yet
# 88
# 89
# 90 YetGen
# 91
# 92
# 93 Yet
# 94
# 95 Gen
# 96 Yet
# 97
# 98
# 99 Yet
# 100 Gen
