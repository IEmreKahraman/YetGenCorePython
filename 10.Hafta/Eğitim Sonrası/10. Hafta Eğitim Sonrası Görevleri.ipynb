# %% [markdown]
# # Problem 1

# %%
# 1
import numpy as np

# 2
array = np.array([12, 3, 45, 7, 23])
print("Orijinal Array:", array)

# 3
sıralı_array = np.sort(array)
print("Sıralanmış Array:", sıralı_array)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 1
# ----> 2 import numpy as np
#       4 # 2
#       5 array = np.array([12, 3, 45, 7, 23])
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# # Problem 2

# %%
import numpy as np

# 1- (10,15,30,45,60) değerlerine sahip numpy dizisi oluşturunuz.
dizi1 = np.array([10, 15, 30, 45, 60])

# 2- (5-15) arasındaki sayılarla numpy dizisi oluşturunuz.
dizi2 = np.arange(5, 16)

# 3- (50-100) arasında 5'er 5'er artarak numpy dizisi oluşturunuz.
dizi3 = np.arange(50, 101, 5)

# 4- 10 elemanlı sıfırlardan oluşan bir dizi oluşturunuz.
dizi4 = np.zeros(10)

# 5- 10 elemanlı birlerden oluşan bir dizi oluşturunuz.
dizi5 = np.ones(10)

# 6- (0-100) arasında eşit aralıklı 5 sayı üretin.
dizi6 = np.linspace(0, 100, 5)

# 7- (10-30) arasında rastgele 5 tane tamsayı üretin.
dizi7 = np.random.randint(10, 31, size=5)

# 8- [-1 ile 1] arasında 10 adet sayı üretin.
dizi8 = np.linspace(-1, 1, 10)

# 9- (3x5) boyutlarında (10-50) arasında rastgele bir matris oluşturunuz.
matris = np.random.randint(10, 51, size=(3, 5))

# 10- Üretilen matrisin satır ve sütun sayıları toplamlarını hesaplayınız ?
satir_toplamlari = matris.sum(axis=1)
sutun_toplamlari = matris.sum(axis=0)

# 11- Üretilen matrisin en büyük, en küçük ve ortalaması nedir ?
en_buyuk = matris.max()
en_kucuk = matris.min()
ortalama = matris.mean()

# 12- Üretilen matrisin en büyük değerinin indeksi kaçtır ?
en_buyuk_indeks = np.unravel_index(matris.argmax(), matris.shape)

# 13- (10-20) arasındaki sayıları içeren dizinin ilk 3 elemanını seçiniz.
dizi13 = np.arange(10, 21)
ilk_uc = dizi13[:3]

# 14- Üretilen dizinin elemanlarını tersten yazdırın.
tersten_dizi = dizi13[::-1]

# 15- Üretilen matrisin ilk satırını seçiniz.
ilk_satir = matris[0]

# 16- Üretilen matrisin 2.satır 3.sütundaki elemanı hangisidir ?
eleman_2x3 = matris[1, 2]

# 17- Üretilen matrisin tüm satırlardaki ilk elemanı seçiniz.
ilk_elemanlar = matris[:, 0]

# 18- Üretilen matrisin her bir elemanının karesini alınız.
kareleri = matris ** 2

# 19- Üretilen matris elemanlarının hangisi pozitif çift sayıdır ? Aralığı (-50,+50) arasında yapınız.
matris_19 = np.random.randint(-50, 51, size=(3, 5))
pozitif_cift_sayilar = matris_19[(matris_19 > 0) & (matris_19 % 2 == 0)]
